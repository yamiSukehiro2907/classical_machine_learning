# %%
import pandas as pd
df = pd.read_csv("Housing.csv")
df.head()
# Out:
#       price  area  bedrooms  ...  parking  prefarea furnishingstatus
# 0  13300000  7420         4  ...        2       yes        furnished
# 1  12250000  8960         4  ...        3        no        furnished
# 2  12250000  9960         3  ...        2       yes   semi-furnished
# 3  12215000  7500         4  ...        3       yes        furnished
# 4  11410000  7420         4  ...        2        no        furnished
#
# [5 rows x 13 columns]

# %%
df.nunique()
# Out:
# price               219
# area                284
# bedrooms              6
# bathrooms             4
# stories               4
# mainroad              2
# guestroom             2
# basement              2
# hotwaterheating       2
# airconditioning       2
# parking               4
# prefarea              2
# furnishingstatus      3
# dtype: int64

# %%
columns = df.columns[df.nunique() < 10]
for i in range(len(columns)):
    df[columns[i]] = df.groupby([columns[i]])['price'].transform('mean')


df.head()
# Out:
#       price  area      bedrooms  ...       parking      prefarea  furnishingstatus
# 0  13300000  7420  5.729758e+06  ...  5.896328e+06  5.879046e+06      5.495696e+06
# 1  12250000  8960  5.729758e+06  ...  5.867167e+06  4.425299e+06      5.495696e+06
# 2  12250000  9960  4.954598e+06  ...  5.896328e+06  5.879046e+06      4.907524e+06
# 3  12215000  7500  5.729758e+06  ...  5.867167e+06  5.879046e+06      5.495696e+06
# 4  11410000  7420  5.729758e+06  ...  5.896328e+06  4.425299e+06      5.495696e+06
#
# [5 rows x 13 columns]

# %%
x = df.drop(axis=1, columns=['price'])
y = df.price

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = scaler.fit_transform(x)
X
# Out:
# array([[0.39656357, 0.9710224 , 0.2489459 , ..., 1.        , 1.        ,
#         1.        ],
#        [0.5024055 , 0.9710224 , 1.        , ..., 0.98343391, 0.        ,
#         1.        ],
#        [0.57113402, 0.72155831, 0.2489459 , ..., 1.        , 1.        ,
#         0.60308668],
#        ...,
#        [0.13539519, 0.29592317, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.08659794, 0.72155831, 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.15120275, 0.72155831, 0.        , ..., 0.        , 0.        ,
#         0.        ]], shape=(545, 12))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.coef_
# Out:
# array([3422222.0516495 ,  553548.05959263, 4044819.1086242 ,
#        1396716.64494807,  426983.04591843,  284467.24328334,
#         362902.88395935,  884067.87484161,  813635.27084503,
#         586349.09453748,  644097.84536162,  440824.14931275])

# %%
lr.intercept_
# Out:
# np.float64(1594711.9766279939)

# %%
lr.tol
# Out:
# 1e-06

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size=0.2 , random_state=2)

# %%
X_train
# Out:
# array([[0.06597938, 0.72155831, 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.42061856, 0.29592317, 0.        , ..., 0.59896911, 0.        ,
#         1.        ],
#        [0.10549828, 0.29592317, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.15876289, 0.72155831, 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.01278351, 0.29592317, 0.        , ..., 0.        , 0.        ,
#         0.60308668],
#        [0.17938144, 0.9710224 , 0.        , ..., 0.        , 0.        ,
#         1.        ]], shape=(436, 12))

# %%
lr.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array