# %%
import pandas as pd
df = pd.read_csv('health.csv')
df.head(20)
# Out:
#     Age            Course  Gender  CGPA  Stress_Level  Depression_Score  \
# 0    25            Others    Male  3.56             3                 3
# 1    24       Engineering  Female  2.44             0                 3
# 2    19          Business  Female  3.74             4                 0
# 3    19  Computer Science    Male  3.65             2                 1
# 4    18          Business    Male  3.40             3                 3
# 5    21           Medical  Female  3.35             2                 4
# 6    18               Law    Male  3.65             2                 2
# 7    21          Business  Female  3.40             0                 3
# 8    24           Medical    Male  3.80             3                 2
# 9    19       Engineering  Female  3.05             2                 5
# 10   23               Law  Female  3.74             3                 2
# 11   28       Engineering  Female   NaN             3                 0
# 12   22  Computer Science    Male  3.19             1                 1
# 13   27           Medical    Male  3.26             3                 2
# 14   24           Medical  Female  3.20             3                 0
# 15   25               Law    Male  3.61             3                 1
# 16   18           Medical  Female  3.85             4                 1
# 17   19           Medical    Male  3.26             5                 1
# 18   22  Computer Science    Male  3.46             3                 1
# 19   20           Medical    Male  3.43             2                 2
#
#     Anxiety_Score Sleep_Quality Physical_Activity Diet_Quality Social_Support  \
# 0               2          Good          Moderate         Good       Moderate
# 1               0       Average               Low      Average            Low
# 2               3          Good               Low      Average       Moderate
# 3               0       Average               Low      Average       Moderate
# 4               4          Good               Low      Average           High
# 5               3          Good          Moderate         Good           High
# 6               5          Good          Moderate      Average       Moderate
# 7               3       Average               Low      Average            Low
# 8               1          Poor               Low      Average       Moderate
# 9               0       Average          Moderate         Good            Low
# 10              4       Average               Low         Good       Moderate
# 11              3       Average          Moderate      Average       Moderate
# 12              3       Average          Moderate      Average       Moderate
# 13              2       Average          Moderate      Average           High
# 14              3       Average               Low         Poor       Moderate
# 15              5          Good               Low      Average       Moderate
# 16              3          Good               Low      Average       Moderate
# 17              1          Good               Low      Average           High
# 18              0          Good          Moderate      Average       Moderate
# 19              2          Good              High      Average            Low
#
#    Relationship_Status Substance_Use Counseling_Service_Use Family_History  \
# 0              Married         Never                  Never             No
# 1               Single  Occasionally           Occasionally             No
# 2    In a Relationship         Never           Occasionally             No
# 3               Single           NaN                  Never             No
# 4              Married         Never                  Never             No
# 5               Single         Never                  Never             No
# 6               Single         Never                  Never             No
# 7              Married         Never                  Never            Yes
# 8               Single    Frequently                  Never            Yes
# 9    In a Relationship           NaN           Occasionally            Yes
# 10   In a Relationship           NaN           Occasionally             No
# 11   In a Relationship         Never           Occasionally            Yes
# 12   In a Relationship         Never           Occasionally             No
# 13   In a Relationship         Never           Occasionally             No
# 14              Single         Never           Occasionally             No
# 15   In a Relationship         Never                  Never            Yes
# 16             Married         Never                  Never            Yes
# 17              Single         Never                  Never            Yes
# 18   In a Relationship         Never             Frequently             No
# 19              Single  Occasionally                  Never             No
#
#    Chronic_Illness  Financial_Stress Extracurricular_Involvement  \
# 0               No                 2                    Moderate
# 1               No                 3                         Low
# 2               No                 4                        High
# 3               No                 4                    Moderate
# 4              Yes                 0                        High
# 5               No                 5                    Moderate
# 6               No                 4                    Moderate
# 7               No                 3                    Moderate
# 8               No                 2                         Low
# 9               No                 1                    Moderate
# 10              No                 3                    Moderate
# 11              No                 0                    Moderate
# 12              No                 1                        High
# 13              No                 1                    Moderate
# 14              No                 2                    Moderate
# 15              No                 4                    Moderate
# 16              No                 1                    Moderate
# 17              No                 4                    Moderate
# 18              No                 4                        High
# 19              No                 3                         Low
#
#     Semester_Credit_Load Residence_Type
# 0                     17      On-Campus
# 1                     27      On-Campus
# 2                     15      On-Campus
# 3                     20     Off-Campus
# 4                     23      On-Campus
# 5                     19     Off-Campus
# 6                     20     Off-Campus
# 7                     23      On-Campus
# 8                     28      On-Campus
# 9                     27     Off-Campus
# 10                    22     Off-Campus
# 11                    20     Off-Campus
# 12                    17      On-Campus
# 13                    17    With Family
# 14                    18      On-Campus
# 15                    25     Off-Campus
# 16                    23     Off-Campus
# 17                    29    With Family
# 18                    29     Off-Campus
# 19                    16    With Family

# %%
df['Stress_Level'].unique()
# Out:
# array([3, 0, 4, 2, 1, 5])

# %%
df.shape
# Out:
# (7022, 20)

# %%
kf = pd.read_csv('test.csv')
kf.head()
# Out:
#    Age  Grade  Gender      Race  SES_Quartile ParentalEducation SchoolType  \
# 0   15     10  Female     White             1                HS     Public
# 1   16     11  Female  Hispanic             1               <HS    Private
# 2   17     12  Female     Black             2                HS     Public
# 3   16     11  Female     White             2                HS     Public
# 4   16     11    Male     Black             3        Bachelors+     Public
#
#   Locale  TestScore_Math  TestScore_Reading  ...       GPA  AttendanceRate  \
# 0   City       72.346053          62.217134  ...  2.521745        0.868836
# 1   City       77.889157          72.748030  ...  3.275626        0.909595
# 2  Rural       72.966587          65.585472  ...  2.974137        0.870952
# 3   Town       96.674049          88.035852  ...  3.676590        1.000000
# 4  Rural       81.989270          77.485372  ...  2.255014        0.897957
#
#    StudyHours  InternetAccess  Extracurricular  PartTimeJob  ParentSupport  \
# 0    0.310172               0                1            1              1
# 1    1.175586               1                1            0              0
# 2    1.112556               1                1            0              0
# 3    1.067679               0                0            0              0
# 4    0.841936               0                1            0              1
#
#    Romantic  FreeTime  GoOut
# 0         0         3      3
# 1         1         3      1
# 2         0         3      3
# 3         1         4      5
# 4         0         4      2
#
# [5 rows x 21 columns]

# %%
kf.columns
# Out:
# Index(['Age', 'Grade', 'Gender', 'Race', 'SES_Quartile', 'ParentalEducation',
#        'SchoolType', 'Locale', 'TestScore_Math', 'TestScore_Reading',
#        'TestScore_Science', 'GPA', 'AttendanceRate', 'StudyHours',
#        'InternetAccess', 'Extracurricular', 'PartTimeJob', 'ParentSupport',
#        'Romantic', 'FreeTime', 'GoOut'],
#       dtype='object')

# %%
kf.shape
# Out:
# (999997, 21)

# %%
test_data = pd.read_csv('test.csv')
train_data = pd.read_csv('train.csv')
validation_csbv = pd.read_csv('validation.csv')

# %%
# print(train_data.columns)
# print(test_data.columns)
# print(validation_csbv.columns)

# print(train_data.shape)
# print(test_data.shape)
# print(validation_csbv.shape)

train_data.head()
# Out:
#    Age  Grade  Gender         Race  SES_Quartile ParentalEducation SchoolType  \
# 0   17     12  Female        White             3                HS     Public
# 1   18     12  Female        White             2                HS     Public
# 2   16     11  Female        White             2                HS     Public
# 3   14      9  Female        White             4        Bachelors+     Public
# 4   16     11  Female  Two-or-more             4       SomeCollege     Public
#
#      Locale  TestScore_Math  TestScore_Reading  ...       GPA  AttendanceRate  \
# 0  Suburban       70.258235          79.665185  ...  2.743879        0.906809
# 1  Suburban       67.876546          59.611505  ...  2.587700        0.843739
# 2      City       62.070623          70.577443  ...  2.426294        0.850923
# 3      Town       79.909312          82.924450  ...  3.558240        0.946786
# 4     Rural       90.562294          95.352336  ...  3.896884        0.988036
#
#    StudyHours  InternetAccess  Extracurricular  PartTimeJob  ParentSupport  \
# 0    1.089243               1                1            0              0
# 1    0.879911               1                1            0              1
# 2    1.003442               1                1            0              1
# 3    1.814810               1                1            0              1
# 4    1.157241               1                1            0              0
#
#    Romantic  FreeTime  GoOut
# 0         0         2      2
# 1         0         5      2
# 2         1         5      1
# 3         0         4      2
# 4         0         3      4
#
# [5 rows x 21 columns]
